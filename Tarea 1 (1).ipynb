# %% [markdown]
# # Promedio Matemático

# %%
[![Open in colab](http://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Nicolas20010606/Diplomado_Ciencia_Datos/blob/main/Tarea%201.ipynb)
# Out:
#   File "C:\Users\PC1\AppData\Local\Temp\ipykernel_10120\2359771948.py", line 1
#     [![Open in colab](http://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Nicolas20010606/Diplomado_Ciencia_Datos/blob/main/Tarea%201.ipynb)
#      ^
# SyntaxError: invalid syntax

# %% [markdown]
# ![python.jfif](attachment:python.jfif)

# %% [markdown]
# ## Autor: Nicolás Alejandro Díaz Ubaque
# ## Ocupación: Estudiante de Estadística
# ## Pasatiempos: Deportes, juegos de video, comida

# %% [markdown]
# ![131624543_1869577353179942_9009194900058212994_n.jpg](attachment:131624543_1869577353179942_9009194900058212994_n.jpg)

# %% [markdown]
# Dado un conjunto de datos cuantitativos, podemos obtener su promedio matemático calculando la suma de todos sus elementos y dividiendola por el número total de los mismos. Así, si tenemos un conjunto con n elementos, calculamos su promedio como
# $$\dfrac{1+2+...+n}{n}$$

# %% [markdown]
# ## Ejemplo:
# Dado el conjunto A=(1,2,3,4,5), calculamos su promedio como
# $$\dfrac{1+2+3+4+5}{5} = \dfrac{15}{5} = 3$$

# %% [markdown]
# # Referencias
# Para obtener más información respecto al promedio matemático, visitar
# https://es.wikipedia.org/wiki/Promedio
